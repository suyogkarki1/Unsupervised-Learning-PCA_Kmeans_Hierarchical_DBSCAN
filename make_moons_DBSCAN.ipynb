# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_moons

# %%
X,y=make_moons(n_samples=250,noise=0.05)

# %%
X.shape
# Out:
# (250, 2)

# %%
plt.scatter(X[:,0],X[:,1])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-1.23605107,  1.29939972],
#        [ 1.52716446, -0.49063372],
#        [ 0.49773665, -1.30743708],
#        [-0.09003955, -0.92424379],
#        [ 0.34903996, -1.43944328],
#        [-1.4570082 ,  0.68207933],
#        [-1.77912887, -0.04947967],
#        [-0.05014587, -1.10626473],
#        [ 1.70914443,  0.29141547],
#        [ 1.58958582, -0.51415497],
#        [ 1.55233186, -0.4965105 ],
#        [ 1.41101864, -0.85693591],
#        [ 0.63262358, -1.43852377],
#        [-1.35931039,  0.93362246],
#        [ 1.44333504, -0.81883761],
#        [ 0.23453866,  1.04484969],
#        [-0.25788581,  1.31758952],
#        [ 0.44695815,  0.12805257],
#        [ 0.47031215,  0.15744569],
#        [-1.41066584,  0.93860522],
#        [-0.30257122,  1.47385441],
#        [ 1.40594804, -0.80326135],
#        [ 0.52771597, -1.41290167],
#        [-1.39240532,  1.02744621],
#        [-0.74361015,  1.38273471],
#        [ 0.87114347, -1.54000938],
#        [ 0.91597677, -1.36514279],
#        [-1.183145  ,  1.35058176],
#        [ 0.0920495 ,  1.22586359],
#        [ 1.00762563, -1.38305253],
#        [ 0.76364536, -1.54695623],
#        [-1.3029659 ,  1.05518726],
#        [-0.06552115, -1.20032865],
#        [-0.06152641, -1.12342711],
#        [-0.02587271, -1.33087177],
#        [ 0.44145483,  0.36127877],
#        [-1.58550443,  0.20818504],
#        [ 0.13402383, -1.45185485],
#        [ 1.47562284, -0.70358622],
#        [ 0.05980652, -1.25594932],
#        [-0.52912694, -0.22097241],
#        [ 0.56019903, -0.4160035 ],
#        [-0.36696263, -0.6571    ],
#        [ 0.35084668, -1.45276921],
#        [-0.51625338,  0.40513982],
#        [-0.50592181, -0.43147548],
#        [-1.58101998,  0.49252667],
#        [-0.90575135,  1.46734996],
#        [ 0.46939507,  0.35374112],
#        [-0.02230994,  1.30750462],
#        [-1.55698318,  0.35592511],
#        [-0.64668556,  0.51886297],
#        [ 0.29178414, -1.43277774],
#        [-0.10301999,  1.18000605],
#        [-1.72010262, -0.32410057],
#        [-1.74878757, -0.18100027],
#        [ 0.53980669,  0.07578713],
#        [-1.83539055, -0.26798778],
#        [-0.66023132,  0.47926186],
#        [-1.13129267,  1.3575452 ],
#        [ 0.21774318,  0.89191053],
#        [-1.24444066,  1.00579431],
#        [-0.02570027, -1.10432706],
#        [-0.07299023,  1.26828449],
#        [ 0.92801763, -1.40796205],
#        [-0.41681218, -0.0058233 ],
#        [ 1.79687962,  0.6207279 ],
#        [ 0.48136345, -0.2282292 ],
#        [ 0.89848276, -1.41583408],
#        [-1.43952882,  1.10633925],
#        [-0.50389095,  0.64066558],
#        [-0.27767832,  1.55731338],
#        [-0.07044114,  1.14790202],
#        [-0.28275893, -0.93391237],
#        [-0.53286511,  0.05027045],
#        [ 1.41387007, -1.02996661],
#        [-0.07530808, -1.04108458],
#        [ 1.3293361 , -1.14275914],
#        [-1.26831213,  1.28552073],
#        [-0.64499701,  1.42966674],
#        [-1.08216744,  1.35886577],
#        [-0.54454837,  1.47210089],
#        [ 1.39000511, -1.02319886],
#        [ 1.06339019, -1.25793377],
#        [ 0.62765343, -0.21968155],
#        [ 0.26430033,  0.79417439],
#        [ 1.6232956 , -0.13307988],
#        [ 1.59688571, -0.15383191],
#        [-1.10151575,  1.360971  ],
#        [-0.52102448, -0.20152451],
#        [ 0.46304133,  0.27968385],
#        [ 0.54293322, -0.25220362],
#        [ 1.77867778,  0.0159063 ],
#        [-0.53313011, -0.27775211],
#        [-1.46243684,  0.56535796],
#        [-0.18305053, -1.1945099 ],
#        [-0.49935337, -0.18365622],
#        [-0.59632943,  0.21798089],
#        [ 0.59368676, -1.63404258],
#        [-1.29760284,  1.02417463],
#        [-0.76563774,  1.33701595],
#        [-1.09964265,  1.27412576],
#        [-0.35458594, -0.54279776],
#        [-1.66561871,  0.44810979],
#        [-0.86344948,  1.4987635 ],
#        [-0.71752916,  1.51128353],
#        [ 0.23643481,  0.94803029],
#        [ 0.56380776,  0.06849949],
#        [-1.53082579,  0.22891406],
#        [-1.19890762,  1.12455021],
#        [ 0.2420478 , -1.44260474],
#        [ 1.79391459,  0.41276034],
#        [-0.44881382,  1.44998401],
#        [ 0.34630125, -1.6007911 ],
#        [-0.68810796,  1.5171461 ],
#        [-1.26785511,  1.07045936],
#        [-0.49545776, -0.22188891],
#        [-1.10687494,  1.2484732 ],
#        [ 1.74159127,  0.04461285],
#        [-0.12080805,  1.30287745],
#        [ 1.85350406,  0.10778422],
#        [ 0.34938785,  0.6619591 ],
#        [ 1.73855283,  0.02363937],
#        [-0.54098028,  0.17397757],
#        [ 1.21079772, -1.28878469],
#        [ 1.26572722, -0.88339721],
#        [ 1.64747858,  0.50603654],
#        [ 0.62057157, -0.09002965],
#        [ 0.67528089,  0.14989014],
#        [-0.22637651,  1.46043568],
#        [-0.24735813, -0.63664498],
#        [ 1.72945409,  0.08024438],
#        [-0.98959872,  1.48708071],
#        [ 1.76102292,  0.18366179],
#        [-1.77939441, -0.26365502],
#        [ 0.50269606,  0.72006105],
#        [ 0.86755781, -1.38853314],
#        [-0.54597653,  0.46757451],
#        [ 0.2886428 ,  0.75003658],
#        [-0.40912579, -0.56804428],
#        [ 0.98054435, -1.50106182],
#        [-0.43661818, -0.44622554],
#        [ 0.29416024,  0.8094099 ],
#        [ 0.38164598,  0.43282742],
#        [-1.74448923, -0.20333551],
#        [ 0.16423729,  1.06823319],
#        [ 1.69710744, -0.00798053],
#        [ 1.18719862, -1.25606747],
#        [ 1.50445131, -0.67343223],
#        [-1.03046329,  1.45259595],
#        [-0.35384286, -0.58229555],
#        [-0.07184384, -0.91056183],
#        [ 0.21099216, -1.42769464],
#        [ 0.56986936, -1.3530973 ],
#        [ 0.43520591,  0.57875356],
#        [ 0.67531117, -1.65542925],
#        [-1.68615682, -0.20987827],
#        [-1.68961675,  0.25307249],
#        [ 0.5345747 , -0.05748188],
#        [-1.03849177,  1.40688759],
#        [-1.17678021,  1.44441711],
#        [-1.68561334,  0.01282811],
#        [-0.35584721,  1.46913289],
#        [-0.23220693,  1.56631731],
#        [ 1.62283182, -0.20475373],
#        [-0.74264294,  1.3662855 ],
#        [-1.69661331, -0.26620311],
#        [ 1.10342905, -1.23745512],
#        [-0.30152933, -1.01533401],
#        [-0.4962531 , -0.19250738],
#        [ 0.5554719 ,  0.4169865 ],
#        [ 0.80669856, -1.68329852],
#        [-0.51199538, -0.27742953],
#        [ 0.27999687,  0.88710707],
#        [-1.50296292,  0.69967453],
#        [-1.52009116,  0.43714468],
#        [-1.48207962,  0.75488243],
#        [ 0.90613513, -1.52453353],
#        [ 0.07781806, -1.21682196],
#        [-1.70376147, -0.56207603],
#        [-0.06673879,  1.2376625 ],
#        [-0.69155639,  1.66606966],
#        [ 0.46267925, -1.63599482],
#        [-1.60296281,  0.7219093 ],
#        [ 1.39348364, -1.11324297],
#        [ 0.43286142, -0.03195996],
#        [-0.60467021,  1.45805802],
#        [-0.18965495,  1.50537507],
#        [ 0.46895378, -0.30177267],
#        [ 1.53481072, -0.86062614],
#        [ 1.56171292, -0.28992616],
#        [-1.41838766,  0.76357936],
#        [-0.27365396, -0.77351049],
#        [-0.44000558,  1.55834562],
#        [-1.7050042 , -0.03431096],
#        [-0.44771862,  1.38101259],
#        [ 0.36342768,  0.32620552],
#        [ 1.26422685, -1.11344258],
#        [ 0.79478196, -1.2942267 ],
#        [-1.13300903,  1.3888444 ],
#        [ 0.34846951, -1.5071977 ],
#        [ 1.55787277, -0.58104858],
#        [-1.6338641 ,  0.59033617],
#        [ 0.87764146, -1.39049836],
#        [ 1.66965498, -0.37904101],
#        [-0.04300728,  1.14475268],
#        [ 1.68306334,  0.46094217],
#        [ 0.28008068, -1.43191046],
#        [-0.25369746, -0.65740058],
#        [ 0.05889527,  1.03376348],
#        [ 1.60324417, -0.56535576],
#        [-1.59917337,  0.25628951],
#        [ 0.26724418, -1.29199704],
#        [ 0.16531432, -1.4793652 ],
#        [-0.47524572,  1.20640803],
#        [-0.46339114,  1.26591255],
#        [ 1.30207244, -1.18450111],
#        [ 0.06741342, -1.24366279],
#        [-1.51938515,  0.09376136],
#        [ 1.40897566, -0.77389082],
#        [-0.40552944, -0.76969204],
#        [-1.57841647,  0.35594933],
#        [-0.50051981,  0.25807717],
#        [ 0.38645443, -1.41802594],
#        [ 1.3909068 , -0.70798252],
#        [ 0.19758966,  1.18829195],
#        [ 1.19475457, -1.30142925],
#        [-1.68974332,  0.09141573],
#        [ 0.07197291, -1.41301223],
#        [ 0.40814851,  0.4394488 ],
#        [ 1.1227715 , -1.40220406],
#        [-0.36289883,  1.61574555],
#        [ 0.23537083,  0.87890505],
#        [-0.96948403,  1.4265585 ],
#        [ 0.70770048, -0.40874963],
#        [ 1.55376332, -0.25221402],
#        [-0.18055596,  1.31795768],
#        [ 1.0861056 , -1.58730027],
#        [ 0.64721191, -0.33500135],
#        [-0.51281557,  0.22408693],
#        [-0.40380543, -0.55696438],
#        [ 0.65366703, -1.38081505],
#        [-0.57308886,  1.33311638],
#        [ 0.08113274,  1.12434771],
#        [-0.4146507 , -0.46678975],
#        [ 0.16216547, -1.42727382],
#        [-0.11486967, -1.07377635],
#        [ 0.26167722,  0.95507538],
#        [ 1.15131065, -1.20135121],
#        [ 0.51797778,  0.26669725]])

# %% [markdown]
# ### DBSCAN

# %%
from sklearn.cluster import DBSCAN

dbscan=DBSCAN(eps=0.5)
dbscan.fit(X_scaled)
label=dbscan.labels_

# %%
plt.scatter(X_scaled[:,0],X_scaled[:,1],c=label)
